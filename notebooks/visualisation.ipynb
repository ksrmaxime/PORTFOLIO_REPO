# %%
import pandas as pd

parquet_PATH = "/Users/maximekaiser/Documents/CODES/PORTFOLIO_REPO/data/processed/fedlex_law_chunks.parquet"
df_laws = pd.read_parquet(parquet_PATH)
df_laws.to_csv("laws.csv", index=False, encoding="utf-8-sig")

# %%
import pandas as pd

parquet_PATH = "/Users/maximekaiser/Documents/CODES/PORTFOLIO_REPO/data/processed/fedlex_articles.parquet"
df_laws = pd.read_parquet(parquet_PATH)
df_laws.to_csv("laws_articles.csv", index=False, encoding="utf-8-sig")
