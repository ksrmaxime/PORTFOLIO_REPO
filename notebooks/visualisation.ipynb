# %%
import pandas as pd

parquet_PATH = "/Users/maximekaiser/Documents/CODES/PORTFOLIO_REPO/data/processed/fedlex/laws_structure_with_title_triage.parquet"
df_laws = pd.read_parquet(parquet_PATH)
df_laws.to_csv("laws_output_LLM.csv", index=False, encoding="utf-8-sig")

# %%
import pandas as pd

parquet_PATH = "/Users/maximekaiser/Documents/CODES/PORTFOLIO_REPO/data/processed/fedlex/laws_structure_with_article_classification.parquet"
df_laws = pd.read_parquet(parquet_PATH)
df_laws.to_csv("RUN2_output_LLM.csv", index=False, encoding="utf-8-sig")

# %%
import pandas as pd

parquet_PATH = "/Users/maximekaiser/Documents/CODES/PORTFOLIO_REPO/data/processed/fedlex/laws_structure.parquet"
df_laws = pd.read_parquet(parquet_PATH)
df_laws.to_csv("laws_input.csv", index=False, encoding="utf-8-sig")

# %%
import pandas as pd

parquet_PATH = "/Users/maximekaiser/Documents/CODES/PORTFOLIO_REPO/data/processed/fedlex/laws_structure_with_article_classification_and_instruments.parquet"
df_laws = pd.read_parquet(parquet_PATH)
df_laws.to_csv("RUN3_output_LLM.csv", index=False, encoding="utf-8-sig")
